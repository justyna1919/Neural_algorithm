# %%
import scipy.io
import seaborn as sns
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import sklearn
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale

# %%
df = pd.read_csv('0hp_all_faults.csv')

# %%
import numpy as np
import pandas as pd
from scipy.fft import fft
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len = 784
stride = 300

X = []
Y = []

for k in df['fault'].unique():
    df_temp_2 = df[df['fault'] == k]

    for i in np.arange(0, len(df_temp_2) - (win_len), stride):
        temp = df_temp_2.iloc[i:i + win_len, :-1].values
        # Przeprowadź FFT na każdej próbce
        temp_fft = np.abs(fft(temp))
        temp_fft = temp_fft.reshape((temp_fft.shape[0], 1))  # Zakładam, że chcesz jednowymiarowy sygnał

        X.append(temp_fft)
        Y.append(df_temp_2.iloc[i + win_len, -1])
        
X=np.array(X)
X=X.reshape((X.shape[0],28,28,1))
Y = np.array(Y)


encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)

# %%
X.shape
# Out:
# (9246, 28, 28, 1)

# %%
from matplotlib.pyplot import imread


for idx in range(0,9244,500):
    img=X[idx]

    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.title(Y[idx])
    plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.3,shuffle=True)

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
no_classes = len(df['fault'].unique())

cnn_model = Sequential()

cnn_model.add(Conv2D(64, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1))) # Warstwa konwolucyjna (Convolutional Layer)
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) # Warstwa sub-sampling (Pooling Layer)
cnn_model.add(Conv2D(32, kernel_size=(5, 5), activation='relu')) # Kolejna warstwa konwolucyjna
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) # Kolejna warstwa sub-sampling
cnn_model.add(Flatten()) # Warstwa spłaszczająca dane przed wejściem do warstw gęstych
cnn_model.add(Dense(120, activation='relu')) # Warstwa gęsta (Fully Connected Layer)
cnn_model.add(Dense(84, activation='relu')) # Kolejna warstwa gęsta
cnn_model.add(Dense(no_classes, activation='softmax')) # Warstwa wyjściowa
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # Kompilacja modelu
cnn_model.summary() # Wyświetlenie struktury modelu
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 24, 24, 64)        1664
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 8, 8, 32)          51232
#
#  max_pooling2d_1 (MaxPoolin  (None, 4, 4, 32)          0
#  g2D)
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 120)               61560
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dense_2 (Dense)             (None, 14)                1190
#
# =================================================================
# Total params: 125810 (491.45 KB)
# Trainable params: 125810 (491.45 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Definiujesz wczesne zatrzymywanie
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Trenujesz model z wczesnym zatrzymaniem
batch_size = 400
epochs = 80
history = cnn_model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, y_test),
    shuffle=True,
    callbacks=[early_stopping]  # Dodajesz wczesne zatrzymywanie do listy callbacks
)
# Out:
# Epoch 1/80
# 17/17 [==============================] - 4s 207ms/step - loss: 2.4534 - accuracy: 0.1151 - val_loss: 2.2395 - val_accuracy: 0.2527
# Epoch 2/80
# 17/17 [==============================] - 3s 183ms/step - loss: 2.0580 - accuracy: 0.3167 - val_loss: 1.7934 - val_accuracy: 0.4272
# Epoch 3/80
# 17/17 [==============================] - 3s 202ms/step - loss: 1.6340 - accuracy: 0.5219 - val_loss: 1.4299 - val_accuracy: 0.5815
# Epoch 4/80
# 17/17 [==============================] - 3s 197ms/step - loss: 1.2343 - accuracy: 0.6350 - val_loss: 0.9607 - val_accuracy: 0.6622
# Epoch 5/80
# 17/17 [==============================] - 3s 192ms/step - loss: 0.8096 - accuracy: 0.7324 - val_loss: 0.6731 - val_accuracy: 0.7541
# Epoch 6/80
# 17/17 [==============================] - 3s 191ms/step - loss: 0.6057 - accuracy: 0.7906 - val_loss: 0.6122 - val_accuracy: 0.7704
# Epoch 7/80
# 17/17 [==============================] - 3s 187ms/step - loss: 0.5306 - accuracy: 0.8120 - val_loss: 0.5168 - val_accuracy: 0.8248
# Epoch 8/80
# 17/17 [==============================] - 3s 187ms/step - loss: 0.4769 - accuracy: 0.8325 - val_loss: 0.4880 - val_accuracy: 0.8349
# Epoch 9/80
# 17/17 [==============================] - 3s 189ms/step - loss: 0.4301 - accuracy: 0.8481 - val_loss: 0.4347 - val_accuracy: 0.8468
# Epoch 10/80
# 17/17 [==============================] - 3s 190ms/step - loss: 0.4190 - accuracy: 0.8500 - val_loss: 0.3972 - val_accuracy: 0.8569
# Epoch 11/80
# 17/17 [==============================] - 3s 191ms/step - loss: 0.4014 - accuracy: 0.8511 - val_loss: 0.3532 - val_accuracy: 0.8756
# Epoch 12/80
# 17/17 [==============================] - 3s 189ms/step - loss: 0.3730 - accuracy: 0.8657 - val_loss: 0.3850 - val_accuracy: 0.8645
# Epoch 13/80
# 17/17 [==============================] - 3s 194ms/step - loss: 0.3697 - accuracy: 0.8608 - val_loss: 0.3805 - val_accuracy: 0.8655
# Epoch 14/80
# 17/17 [==============================] - 3s 204ms/step - loss: 0.3560 - accuracy: 0.8679 - val_loss: 0.3325 - val_accuracy: 0.8825
# Epoch 15/80
# 17/17 [==============================] - 3s 194ms/step - loss: 0.3246 - accuracy: 0.8838 - val_loss: 0.3317 - val_accuracy: 0.8760
# Epoch 16/80
# 17/17 [==============================] - 3s 197ms/step - loss: 0.3087 - accuracy: 0.8889 - val_loss: 0.3242 - val_accuracy: 0.8854
# Epoch 17/80
# 17/17 [==============================] - 3s 190ms/step - loss: 0.3203 - accuracy: 0.8826 - val_loss: 0.3596 - val_accuracy: 0.8670
# Epoch 18/80
# 17/17 [==============================] - 3s 194ms/step - loss: 0.3344 - accuracy: 0.8773 - val_loss: 0.3715 - val_accuracy: 0.8785
# Epoch 19/80
# 17/17 [==============================] - 4s 207ms/step - loss: 0.3049 - accuracy: 0.8903 - val_loss: 0.3065 - val_accuracy: 0.8875
# Epoch 20/80
# 17/17 [==============================] - 3s 202ms/step - loss: 0.2924 - accuracy: 0.8949 - val_loss: 0.2958 - val_accuracy: 0.8922
# Epoch 21/80
# 17/17 [==============================] - 3s 200ms/step - loss: 0.2734 - accuracy: 0.9031 - val_loss: 0.3155 - val_accuracy: 0.8818
# Epoch 22/80
# 17/17 [==============================] - 3s 195ms/step - loss: 0.2897 - accuracy: 0.8943 - val_loss: 0.2849 - val_accuracy: 0.8915
# Epoch 23/80
# 17/17 [==============================] - 3s 196ms/step - loss: 0.2589 - accuracy: 0.9079 - val_loss: 0.2603 - val_accuracy: 0.9074
# Epoch 24/80
# 17/17 [==============================] - 4s 209ms/step - loss: 0.2540 - accuracy: 0.9087 - val_loss: 0.3700 - val_accuracy: 0.8533
# Epoch 25/80
# 17/17 [==============================] - 4s 227ms/step - loss: 0.2918 - accuracy: 0.8945 - val_loss: 0.3347 - val_accuracy: 0.8771
# Epoch 26/80
# 17/17 [==============================] - 3s 206ms/step - loss: 0.2838 - accuracy: 0.8960 - val_loss: 0.2620 - val_accuracy: 0.9037
# Epoch 27/80
# 17/17 [==============================] - 4s 213ms/step - loss: 0.2475 - accuracy: 0.9073 - val_loss: 0.2586 - val_accuracy: 0.9056
# Epoch 28/80
# 17/17 [==============================] - 4s 215ms/step - loss: 0.2385 - accuracy: 0.9113 - val_loss: 0.2546 - val_accuracy: 0.9124
# Epoch 29/80
# 17/17 [==============================] - 3s 205ms/step - loss: 0.2356 - accuracy: 0.9108 - val_loss: 0.2319 - val_accuracy: 0.9153
# Epoch 30/80
# 17/17 [==============================] - 3s 197ms/step - loss: 0.2155 - accuracy: 0.9204 - val_loss: 0.2337 - val_accuracy: 0.9120
# Epoch 31/80
# 17/17 [==============================] - 3s 196ms/step - loss: 0.2104 - accuracy: 0.9231 - val_loss: 0.2452 - val_accuracy: 0.9088
# Epoch 32/80
# 17/17 [==============================] - 3s 203ms/step - loss: 0.2076 - accuracy: 0.9232 - val_loss: 0.2286 - val_accuracy: 0.9142
# Epoch 33/80
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2058 - accuracy: 0.9231 - val_loss: 0.2207 - val_accuracy: 0.9207
# Epoch 34/80
# 17/17 [==============================] - 3s 199ms/step - loss: 0.2051 - accuracy: 0.9212 - val_loss: 0.2216 - val_accuracy: 0.9174
# Epoch 35/80
# 17/17 [==============================] - 3s 193ms/step - loss: 0.1979 - accuracy: 0.9274 - val_loss: 0.3007 - val_accuracy: 0.8882
# Epoch 36/80
# 17/17 [==============================] - 3s 201ms/step - loss: 0.2266 - accuracy: 0.9146 - val_loss: 0.2206 - val_accuracy: 0.9156
# Epoch 37/80
# 17/17 [==============================] - 3s 203ms/step - loss: 0.1976 - accuracy: 0.9278 - val_loss: 0.2109 - val_accuracy: 0.9225
# Epoch 38/80
# 17/17 [==============================] - 4s 213ms/step - loss: 0.1832 - accuracy: 0.9325 - val_loss: 0.2513 - val_accuracy: 0.9019
# Epoch 39/80
# 17/17 [==============================] - 3s 205ms/step - loss: 0.1911 - accuracy: 0.9297 - val_loss: 0.2297 - val_accuracy: 0.9142
# Epoch 40/80
# 17/17 [==============================] - 3s 199ms/step - loss: 0.1937 - accuracy: 0.9277 - val_loss: 0.2129 - val_accuracy: 0.9182
# Epoch 41/80
# 17/17 [==============================] - 3s 202ms/step - loss: 0.1869 - accuracy: 0.9289 - val_loss: 0.2400 - val_accuracy: 0.9171
# Epoch 42/80
# 17/17 [==============================] - 3s 204ms/step - loss: 0.1968 - accuracy: 0.9277 - val_loss: 0.2938 - val_accuracy: 0.8991

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred


y_pred=cnn_model.predict(X_test)


Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)


from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_, cmap='BuPu', fmt='.2f')
plt.title('Macierz pomyłek')
plt.xlabel('Przewidziana klasa')
plt.ylabel('Poprawna klasa')
# Out:
# 87/87 [==============================] - 1s 7ms/step
# Text(95.72222222222221, 0.5, 'Poprawna klasa')

# %%
plt.title('Krzywa strat uczenia')
plt.xlabel('Numer epoki')
plt.ylabel("Błąd uczenia")
plt.plot(history.history['loss'])
plt.grid(color='k', linestyle='--', linewidth=0.5)

# %%
plt.title('Krzywa dokładności uczenia')
plt.plot(history.history['accuracy'],'go--')
plt.plot(history.history['val_accuracy'],'ro--')
plt.legend(['Dokładność dla zestawu uczącego','Dokładność dla zestawu walidacyjnego'])
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.show()

# %%
dummy_cnn = Model(inputs=cnn_model.input,outputs=cnn_model.layers[5].output)
y_viz = dummy_cnn.predict(X_train)
from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

tSNEdf['Fault']=inv_Transform_result(y_train)


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()
# Out:
# 203/203 [==============================] - 1s 6ms/step
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 6472 samples in 0.000s...
# [t-SNE] Computed neighbors for 6472 samples in 0.447s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 6472
# [t-SNE] Computed conditional probabilities for sample 2000 / 6472
# [t-SNE] Computed conditional probabilities for sample 3000 / 6472
# [t-SNE] Computed conditional probabilities for sample 4000 / 6472
# [t-SNE] Computed conditional probabilities for sample 5000 / 6472
# [t-SNE] Computed conditional probabilities for sample 6000 / 6472
# [t-SNE] Computed conditional probabilities for sample 6472 / 6472
# [t-SNE] Mean sigma: 0.978882
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 68.113121
# [t-SNE] KL divergence after 300 iterations: 2.101086

# %%
df = pd.read_csv('1hp_all_faults.csv')

# %%
import numpy as np
import pandas as pd
from scipy.fft import fft
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len = 784
stride = 300

X = []
Y = []

for k in df['fault'].unique():
    df_temp_2 = df[df['fault'] == k]

    for i in np.arange(0, len(df_temp_2) - (win_len), stride):
        temp = df_temp_2.iloc[i:i + win_len, :-1].values
        # Przeprowadź FFT na każdej próbce
        temp_fft = np.abs(fft(temp))
        temp_fft = temp_fft.reshape((temp_fft.shape[0], 1))  # Zakładam, że chcesz jednowymiarowy sygnał

        X.append(temp_fft)
        Y.append(df_temp_2.iloc[i + win_len, -1])
        
X=np.array(X)
X=X.reshape((X.shape[0],28,28,1))
Y = np.array(Y)


encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)

# %%
from matplotlib.pyplot import imread


for idx in range(0,9244,500):
    img=X[idx]

    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.title(Y[idx])
    plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.3,shuffle=True)

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
no_classes = len(df['fault'].unique())

cnn_model = Sequential()

cnn_model.add(Conv2D(64, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1))) # Warstwa konwolucyjna (Convolutional Layer)
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) # Warstwa sub-sampling (Pooling Layer)
cnn_model.add(Conv2D(32, kernel_size=(5, 5), activation='relu')) # Kolejna warstwa konwolucyjna
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) # Kolejna warstwa sub-sampling
cnn_model.add(Flatten()) # Warstwa spłaszczająca dane przed wejściem do warstw gęstych
cnn_model.add(Dense(120, activation='relu')) # Warstwa gęsta (Fully Connected Layer)
cnn_model.add(Dense(84, activation='relu')) # Kolejna warstwa gęsta
cnn_model.add(Dense(no_classes, activation='softmax')) # Warstwa wyjściowa
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # Kompilacja modelu
cnn_model.summary() # Wyświetlenie struktury modelu

# %%
# Definiujesz wczesne zatrzymywanie
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Trenujesz model z wczesnym zatrzymaniem
batch_size = 400
epochs = 80
history = cnn_model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, y_test),
    shuffle=True,
    callbacks=[early_stopping]  # Dodajesz wczesne zatrzymywanie do listy callbacks
)

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=cnn_model.predict(X_test)


Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_, cmap='BuPu', fmt='.2f')
plt.title('Macierz pomyłek')
plt.xlabel('Przewidziana klasa')
plt.ylabel('Poprawna klasa')

# %%
plt.title('Krzywa strat uczenia')
plt.xlabel('Numer epoki')
plt.ylabel("Błąd uczenia")
plt.plot(history.history['loss'])
plt.grid(color='k', linestyle='--', linewidth=0.5)

# %%
plt.title('Krzywa dokładności uczenia')
plt.plot(history.history['accuracy'],'go--')
plt.plot(history.history['val_accuracy'],'ro--')
plt.legend(['Dokładność dla zestawu uczącego','Dokładność dla zestawu walidacyjnego'])
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.show()

# %%
dummy_cnn = Model(inputs=cnn_model.input,outputs=cnn_model.layers[5].output)
y_viz = dummy_cnn.predict(X_train)
from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

tSNEdf['Fault']=inv_Transform_result(y_train)


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()

# %%
df = pd.read_csv('2hp_all_faults.csv')

# %%
import numpy as np
import pandas as pd
from scipy.fft import fft
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len = 784
stride = 300

X = []
Y = []

for k in df['fault'].unique():
    df_temp_2 = df[df['fault'] == k]

    for i in np.arange(0, len(df_temp_2) - (win_len), stride):
        temp = df_temp_2.iloc[i:i + win_len, :-1].values
        # Przeprowadź FFT na każdej próbce
        temp_fft = np.abs(fft(temp))
        temp_fft = temp_fft.reshape((temp_fft.shape[0], 1))  # Zakładam, że chcesz jednowymiarowy sygnał

        X.append(temp_fft)
        Y.append(df_temp_2.iloc[i + win_len, -1])
        
X=np.array(X)
X=X.reshape((X.shape[0],28,28,1))
Y = np.array(Y)


encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)

# %%
from matplotlib.pyplot import imread


for idx in range(0,9244,500):
    img=X[idx]

    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.title(Y[idx])
    plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.3,shuffle=True)

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
no_classes = len(df['fault'].unique())

cnn_model = Sequential()

cnn_model.add(Conv2D(64, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1))) # Warstwa konwolucyjna (Convolutional Layer)
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) # Warstwa sub-sampling (Pooling Layer)
cnn_model.add(Conv2D(32, kernel_size=(5, 5), activation='relu')) # Kolejna warstwa konwolucyjna
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) # Kolejna warstwa sub-sampling
cnn_model.add(Flatten()) # Warstwa spłaszczająca dane przed wejściem do warstw gęstych
cnn_model.add(Dense(120, activation='relu')) # Warstwa gęsta (Fully Connected Layer)
cnn_model.add(Dense(84, activation='relu')) # Kolejna warstwa gęsta
cnn_model.add(Dense(no_classes, activation='softmax')) # Warstwa wyjściowa
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # Kompilacja modelu
cnn_model.summary() # Wyświetlenie struktury modelu

# %%
# Definiujesz wczesne zatrzymywanie
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Trenujesz model z wczesnym zatrzymaniem
batch_size = 400
epochs = 80
history = cnn_model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, y_test),
    shuffle=True,
    callbacks=[early_stopping]  # Dodajesz wczesne zatrzymywanie do listy callbacks
)

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=cnn_model.predict(X_test)


Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_, cmap='BuPu', fmt='.2f')
plt.title('Macierz pomyłek')
plt.xlabel('Przewidziana klasa')
plt.ylabel('Poprawna klasa')

# %%
plt.title('Krzywa strat uczenia')
plt.xlabel('Numer epoki')
plt.ylabel("Błąd uczenia")
plt.plot(history.history['loss'])
plt.grid(color='k', linestyle='--', linewidth=0.5)

# %%
plt.title('Krzywa dokładności uczenia')
plt.plot(history.history['accuracy'],'go--')
plt.plot(history.history['val_accuracy'],'ro--')
plt.legend(['Dokładność dla zestawu uczącego','Dokładność dla zestawu walidacyjnego'])
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.show()

# %%
dummy_cnn = Model(inputs=cnn_model.input,outputs=cnn_model.layers[5].output)
y_viz = dummy_cnn.predict(X_train)
from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

tSNEdf['Fault']=inv_Transform_result(y_train)


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()

# %%
df = pd.read_csv('3hp_all_faults.csv')

# %%
import numpy as np
import pandas as pd
from scipy.fft import fft
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

win_len = 784
stride = 300

X = []
Y = []

for k in df['fault'].unique():
    df_temp_2 = df[df['fault'] == k]

    for i in np.arange(0, len(df_temp_2) - (win_len), stride):
        temp = df_temp_2.iloc[i:i + win_len, :-1].values
        # Przeprowadź FFT na każdej próbce
        temp_fft = np.abs(fft(temp))
        temp_fft = temp_fft.reshape((temp_fft.shape[0], 1))  # Zakładam, że chcesz jednowymiarowy sygnał

        X.append(temp_fft)
        Y.append(df_temp_2.iloc[i + win_len, -1])
        
X=np.array(X)
X=X.reshape((X.shape[0],28,28,1))
Y = np.array(Y)


encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)
OHE_Y = to_categorical(encoded_Y)

# %%
from matplotlib.pyplot import imread


for idx in range(0,9244,500):
    img=X[idx]

    plt.imshow(img, cmap='gray')
    plt.axis('off')
    plt.title(Y[idx])
    plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,OHE_Y,test_size=0.3,shuffle=True)

# %%
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import Input,Dense, Dropout, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping

# %%
no_classes = len(df['fault'].unique())

cnn_model = Sequential()

cnn_model.add(Conv2D(64, kernel_size=(5, 5), activation='relu', input_shape=(28, 28, 1))) # Warstwa konwolucyjna (Convolutional Layer)
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) # Warstwa sub-sampling (Pooling Layer)
cnn_model.add(Conv2D(32, kernel_size=(5, 5), activation='relu')) # Kolejna warstwa konwolucyjna
cnn_model.add(MaxPooling2D(pool_size=(2, 2))) # Kolejna warstwa sub-sampling
cnn_model.add(Flatten()) # Warstwa spłaszczająca dane przed wejściem do warstw gęstych
cnn_model.add(Dense(120, activation='relu')) # Warstwa gęsta (Fully Connected Layer)
cnn_model.add(Dense(84, activation='relu')) # Kolejna warstwa gęsta
cnn_model.add(Dense(no_classes, activation='softmax')) # Warstwa wyjściowa
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']) # Kompilacja modelu
cnn_model.summary() # Wyświetlenie struktury modelu

# %%
# Definiujesz wczesne zatrzymywanie
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Trenujesz model z wczesnym zatrzymaniem
batch_size = 400
epochs = 80
history = cnn_model.fit(
    X_train, y_train,
    batch_size=batch_size,
    epochs=epochs,
    verbose=1,
    validation_data=(X_test, y_test),
    shuffle=True,
    callbacks=[early_stopping]  # Dodajesz wczesne zatrzymywanie do listy callbacks
)

# %%
def inv_Transform_result(y_pred):    
    y_pred = y_pred.argmax(axis=1)
    y_pred = encoder.inverse_transform(y_pred)
    return y_pred



y_pred=cnn_model.predict(X_test)


Y_pred=inv_Transform_result(y_pred)
Y_test = inv_Transform_result(y_test)




from sklearn.metrics import confusion_matrix


plt.figure(figsize=(10,10))
cm = confusion_matrix(Y_test, Y_pred,normalize='true')
f = sns.heatmap(cm, annot=True,xticklabels=encoder.classes_,yticklabels=encoder.classes_, cmap='BuPu', fmt='.2f')
plt.title('Macierz pomyłek')
plt.xlabel('Przewidziana klasa')
plt.ylabel('Poprawna klasa')

# %%
plt.title('Krzywa strat uczenia')
plt.xlabel('Numer epoki')
plt.ylabel("Błąd uczenia")
plt.plot(history.history['loss'])
plt.grid(color='k', linestyle='--', linewidth=0.5)

# %%
plt.title('Krzywa dokładności uczenia')
plt.plot(history.history['accuracy'],'go--')
plt.plot(history.history['val_accuracy'],'ro--')
plt.legend(['Dokładność dla zestawu uczącego','Dokładność dla zestawu walidacyjnego'])
plt.grid(color='k', linestyle='--', linewidth=0.5)
plt.show()

# %%
dummy_cnn = Model(inputs=cnn_model.input,outputs=cnn_model.layers[5].output)
y_viz = dummy_cnn.predict(X_train)
from sklearn.manifold import TSNE

X_t_sne = TSNE(n_components=2, learning_rate='auto',verbose=1, perplexity=40, n_iter=300).fit_transform(y_viz)

tSNEdf = pd.DataFrame(data = X_t_sne, columns = ['T-SNE component 1', 'T-SNE component 2'])

tSNEdf['Fault']=inv_Transform_result(y_train)


# Plot the PC-1 and PC-2
fig, ax = plt.subplots(figsize=(10,10))
sns.scatterplot(x=tSNEdf['T-SNE component 1'],y=tSNEdf['T-SNE component 2'],hue='Fault',
    data=tSNEdf,
    legend="full",
    alpha=0.3)
plt.show()

# %%
models = ('A', 'B', 'C', 'D') 
FFT_data = {
'FFT_train_accouracy' : (91.22, 92.58, 90.17, 90.03),
'FFT_test_accuracy' : (90.09, 86.36, 87.60, 88.06),
}
   
x = np.arange(len(models))
width = 0.4
multiplier = 0
fig, ax = plt.subplots(layout = 'constrained')
for attribute, measurement in FFT_data.items():
    offset = width * multiplier
    rects= ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1
    
ax.set_ylabel('Dokładność [%]')
ax.set_xlabel('Zbiór danych')
ax.set_title('Zbiór treningowy vs zbiór testowy')
ax.set_xticks(x + width, models)
ax.legend(loc='upper right', ncols=3)
ax.set_ylim(0, 115)
plt.show()
